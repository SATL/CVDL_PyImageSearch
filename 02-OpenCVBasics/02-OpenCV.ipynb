# %% [markdown]
# # Open CV Basics

# %% [markdown]
# ### Imports

# %%
import imutils
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ### Constants

# %%
PATH = '/Users/slem/Code/Learn/DataScience/CVDL_PyImageSearch/02-OpenCVBasics' 
IMG = '/image.jpg'

# %% [markdown]
# ## Display image

# %%
image = cv2.imread(PATH+IMG)
(h,w,d) = image.shape
print("width={}, height={}, depth={}".format(w,h,d))
plt.imshow(image)
# Out:
# width=780, height=1052, depth=3
